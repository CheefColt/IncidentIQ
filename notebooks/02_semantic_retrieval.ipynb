# %%
from incidentiq.search import SearchEngine
DATA_PATH = r"E:\incidentiq\data\processed\logs.parquet"
engine = SearchEngine(DATA_PATH)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 10451.51it/s]
# Batches: 100%|██████████| 63/63 [00:04<00:00, 14.49it/s]

# %%
engine.semantic.search(
    "hardware stopped working",
    top_k=50
)
# Out:
# ([1407,
#   1219,
#   1329,
#   1216,
#   1230,
#   1229,
#   1227,
#   620,
#   1218,
#   1948,
#   457,
#   1406,
#   521,
#   1221,
#   1224,
#   450,
#   1220,
#   1259,
#   1519,
#   1756,
#   1739,
#   1747,
#   1985,
#   1202,
#   1258,
#   238,
#   233,
#   232,
#   231,
#   234,
#   1029,
#   1982,
#   1962,
#   1745,
#   1480,
#   1459,
#   1370,
#   1483,
#   1371,
#   1373,
#   1456,
#   314,
#   837,
#   1402,
#   1514,
#   1069,
#   1281,
#   1234,
#   1261,
#   1495],
#  tensor([0.1999, 0.1999, 0.1999,  ..., 0.1999, 0.1999, 0.0405]))
